# %% [markdown]
# REGULA FALSI

# %%
from IPython.display import Image

# %%
Image('Desktop/regula.jpeg', width = 300, height = 200)

# %%
Image('Desktop/falsi.jpeg', width = 300, height = 200)

# %% [markdown]
# Ejercicio 1

# %%
def f(x):
    return x**3 - 16*x + 3
def falsi(a,b):
    x = 0
    i = 1
    condition = True
    while condition:
        g = str(x)
        x = a-((b-a)/(f(b)-f(a)))*f(a)
        if f(x)<0:
            a = x
        else:
            b = x
        print("i = ", i, "x = ", x, "f(x) = ", f(x))
        
        m = str(x)
        if m[0:n+2]==g[0:n+2]:
            condition = False
        else:
            condition = True
            i = i+1
            
    x = str(x)
    print("Raiz =", x[0:n+2])

a = input("Primera aproximacion : ")
b = input("Segunda aproximacion : ")
n = input("Numero de decimales correctos : ")
a = float(a)
b = float(b)
n = int(n)

if f(a)*f(b)>0:
    print("Prueba con valores diferentes")
else:
    falsi(a,b)
# Out:
# Primera aproximacion :  4
# Segunda aproximacion :  3
# Numero de decimales correctos :  5
# i =  1 x =  3.857142857142857 f(x) =  -1.3294460641399368
# i =  2 x =  3.925498426023085 f(x) =  0.6821419272057199
# i =  3 x =  3.9023186299158263 f(x) =  -0.012236083406172327
# i =  4 x =  3.9027270960742757 f(x) =  -0.00010910951757381326
# i =  5 x =  3.9027307377965914 f(x) =  -9.72655790576482e-07
# i =  6 x =  3.902730770260645 f(x) =  -8.670710371916357e-09
# Raiz  3.90273

# %%
import numpy as np
import matplotlib.pyplot as my

# %%
x = np.linspace(0, 20, 100)
my.plot(x, x**3 - 16*x + 3)
my.grid()
my.show()

# %% [markdown]
# Ejercicio 2

# %%
def f(x):
    return x**3 - 12*x**2 + 1
def falsi(a,b):
    x = 0
    i = 1
    condition = True
    while condition:
        g = str(x)
        x = a-((b-a)/(f(b)-f(a)))*f(a)
        if f(x)<0:
            a = x
        else:
            b = x
        print("i = ", i, "x = ", x, "f(x) = ", f(x))
        
        m = str(x)
        if m[0:n+2]==g[0:n+2]:
            condition = False
        else:
            condition = True
            i = i+1
            
    x = str(x)
    print("Raiz =", x[0:n+2])

a = input("Primera aproximacion : ")
b = input("Segunda aproximacion : ")
n = input("Numero de decimales correctos : ")
a = float(a)
b = float(b)
n = int(n)

if f(a)*f(b)>0:
    print("Prueba con valores diferentes")
else:
    falsi(a,b)
# Out:
# Primera aproximacion :  1
# Segunda aproximacion :  0
# Numero de decimales correctos :  3
# i =  1 x =  0.09090909090909083 f(x) =  0.9015777610818935
# i =  2 x =  0.16609235010337697 f(x) =  0.6735419094919943
# i =  3 x =  0.21871515850326329 f(x) =  0.4364266817240071
# i =  4 x =  0.2513866428392566 f(x) =  0.2575435099064366
# i =  5 x =  0.27018261590822956 f(x) =  0.1437392138493947
# i =  6 x =  0.2805243030150655 f(x) =  0.07774893213887901
# i =  7 x =  0.2860749937017586 f(x) =  0.041345239122813626
# i =  8 x =  0.28901457992235313 f(x) =  0.02178809348105859
# i =  9 x =  0.29056031374268787 f(x) =  0.011427089403997615
# i =  10 x =  0.29137007149742256 f(x) =  0.00597808191103788
# i =  11 x =  0.2917934431780842 f(x) =  0.003123328003104553
# Raiz = 0.291

# %%
x = np.linspace(1, 20, 100)
my.plot(x, x**3 - 12*x**2 + 1)
my.grid()
my.show()
